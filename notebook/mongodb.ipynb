# %%
import pandas as pd
import os

# %%
'''
mongodb+srv://mohamedhma99:321Soufinane_@cluster0.zbjqo.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0
'''
# Out:
# '\nmongodb+srv://mohamedhma99:321Soufinane_@cluster0.zbjqo.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0\n'

# %%
df=pd.read_parquet('hotel_bookings.parquet')
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
#mongdb accept dictionnary format

data_dict=df.to_dict(orient="records")

data_dict
# Out:
# [{'hotel': 'Resort Hotel',
#   'is_canceled': 0,
#   'lead_time': 342,
#   'arrival_date_year': 2015,
#   'arrival_date_month': 'July',
#   'arrival_date_week_number': 27,
#   'arrival_date_day_of_month': 1,
#   'stays_in_weekend_nights': 0,
#   'stays_in_week_nights': 0,
#   'adults': 2,
#   'children': 0.0,
#   'babies': 0,
#   'meal': 'BB',
#   'country': 'PRT',
#   'market_segment': 'Direct',
#   'distribution_channel': 'Direct',
#   'is_repeated_guest': 0,
#   'previous_cancellations': 0,
#   'previous_bookings_not_canceled': 0,
#   'reserved_room_type': 'C',
#   'assigned_room_type': 'C',
#   'booking_changes': 3,
#   'deposit_type': 'No Deposit',
#   'agent': nan,
#   'company': nan,
#   'days_in_waiting_list': 0,
#   'customer_type': 'Transient',
#   'adr': 0.0,
#   'required_car_parking_spaces': 0,
#   'total_of_special_requests': 0,
#   'reservation_status': 'Check-Out',
#   'reservation_status_date': '2015-07-01'},
#  {'hotel': 'Resort Hotel',
#   'is_canceled': 0,
# ...

# %%
len(data_dict)
# Out:
# 119390

# %%
DB_NAME='hotel_cancellation'

COLLECTION_NAME="hotel_cancellation"

CONNECTION_URL="mongodb+srv://mohamedhma99:321Soufinane_@cluster0.zbjqo.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import pymongo
from pymongo.errors import ConnectionFailure, AutoReconnect,BulkWriteError

client = pymongo.MongoClient(CONNECTION_URL, serverSelectionTimeoutMS=5000)
database = client[DB_NAME]
collection = database[COLLECTION_NAME]

batchsize=10000

for i in range(0,len(data_dict),batchsize):

    batch=data_dict[i:i+batchsize]

    try:

        result=collection.insert_many(batch,ordered=False)

    except BulkWriteError as bwe:

        print(f"errors insterting batch {i//batchsize+1}:{bwe.details}")

# %%
records=collection.find()

len(list(records))
# Out:
# 119390

# %%
df=pd.DataFrame(list(collection.find()))

df.head()
# Out:
#                         _id         hotel  is_canceled  lead_time  \
# 0  6702da4d39d5de9e0841813b  Resort Hotel            0        342
# 1  6702da4d39d5de9e0841813c  Resort Hotel            0        737
# 2  6702da4d39d5de9e0841813d  Resort Hotel            0          7
# 3  6702da4d39d5de9e0841813e  Resort Hotel            0         13
# 4  6702da4d39d5de9e0841813f  Resort Hotel            0         14
#
#    arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0               2015               July                        27
# 1               2015               July                        27
# 2               2015               July                        27
# 3               2015               July                        27
# 4               2015               July                        27
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# ...

# %%
df=df.drop(columns='_id',axis=1)

# %%
len(df)
# Out:
# 119390
